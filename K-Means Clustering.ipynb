# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#pblm:Understand the target customers for the marketing team to plan a strategy
#context:to identify the important shopping groups based on income, age and spending score.
#identify the ideal no of grps with a label for each

# %%
df=pd.read_csv('Mall_Customers.csv')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#for any file to be used in python need to be first uploaded in the homepage,only then it could be ran or else and error msg would popup

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.head(10)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# # Univariate Analysis

# %%
genders=df.Gender.value_counts()

# %%
sns.barplot(x=genders.index,y=genders.values)
# Out:
# <Axes: xlabel='Gender'>

# %%
min(df.Age)
# Out:
# 18

# %%
max(df.Age)
# Out:
# 70

# %%
#You need to set bins for x-axis from a category for eg:Age and define them

# %%
Age18_25=df.Age[(df.Age<=25)&(df.Age>=18)]

# %%
Age26_35=df.Age[(df.Age<=35)&(df.Age>=26)]

# %%
Age36_45=df.Age[(df.Age<=45)&(df.Age>=36)]

# %%
Age46_55=df.Age[(df.Age<=55)&(df.Age>=46)]

# %%
Age55above=df.Age[(df.Age>=56)]

# %%
#like in gender the x axis has just two sections male and female and compared against their count in y axis,
#here we should compare the different ages with the count of persons that exist within that range
#eg:length of values from a particular bin

# %%
x=["18-25","26-35","36-45","46-55","Above 55"]
y=[len(Age18_25.values),len(Age26_35.values),len(Age36_45.values),len(Age46_55.values),len(Age55above.values)]

# %%
plt.figure(figsize=(15,6))
plt.title("Number of customer and Ages")
plt.xlabel("Ages")
plt.ylabel("No of Customers")
sns.barplot(x=x,y=y)
plt.show()

# %%
#To show columns from certain range i.e from index 145-170 we can use iloc

# %%
df.iloc[0:15]
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 8            9    Male   64                  19                       3
# 9           10  Female   30                  19                      72
# 10          11    Male   67                  19                      14
# 11          12  Female   35                  19                      99
# ...

# %%
list(df.columns)
# Out:
# ['CustomerID', 'Gender', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']

# %%
AnnualIncome0_30=df["Annual Income (k$)"][(df["Annual Income (k$)"]<=30)&(df["Annual Income (k$)"]>=0)]
AnnualIncome31_60=df["Annual Income (k$)"][(df["Annual Income (k$)"]<=60)&(df["Annual Income (k$)"]>=31)]
AnnualIncome61_90=df["Annual Income (k$)"][(df["Annual Income (k$)"]<=90)&(df["Annual Income (k$)"]>=61)]
AnnualIncome91_120=df["Annual Income (k$)"][(df["Annual Income (k$)"]<=120)&(df["Annual Income (k$)"]>=91)]
AnnualIncome120above=df["Annual Income (k$)"][(df["Annual Income (k$)"]>=121)]

# %%
x=["0-30","31-60","61-90","91-120","Above 120"]
y=[len(AnnualIncome0_30.values),len(AnnualIncome31_60.values),len(AnnualIncome61_90.values),
   len(AnnualIncome91_120.values),len(AnnualIncome120above.values)]

# %%
plt.figure(figsize=(15,6))
plt.title("Number of customer and Annual Income (k$)")
plt.xlabel("Annual Income (k$)")
plt.ylabel("No of Customers")
sns.barplot(x=x,y=y)
plt.show()

# %%
sns.distplot(df['Annual Income (k$)'])
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Density'>

# %%
#Inorder to verify multiple parameters using distplot you need to set columns as a list and apply as i in the
#formula "for i in columns" and then give df[i]

# %%
columns = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']
for i in columns:
    plt.figure()
    sns.distplot(df[i])

# %%
#If we want to observe the parameter by apllying filter using another parameter we can use the 
#kdeplot from Seaborn

# %%
sns.kdeplot(df['Annual Income (k$)'],shade=True);

# %%
columns = ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']
for i in columns:
    plt.figure()
    sns.boxplot(data=df,x='Gender',y=df[i])

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# Female    0.56
# Male      0.44
# Name: proportion, dtype: float64

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(data=df,x='Annual Income (k$)',y='Spending Score (1-100)')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
X = df.iloc[:,[3,4]].values

# %%
X
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
from sklearn.cluster import KMeans
wcss = []

# %%
#you can give the no of clusters by setting KMeans initially

# %%
for i in range(1,5):
    kmeans=KMeans(n_clusters= i, init='k-means++', random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('The elbow method')
plt.xlabel('No of clusters')
plt.ylabel('WCSS Values')
plt.show()

# %%
kmeansmode1= KMeans(n_clusters=5, init='k-means++', random_state=0)

# %%
y_kmeans = kmeansmode1.fit_predict(X)

# %%
plt.scatter(X[y_kmeans == 0,0], X[y_kmeans  == 0,1], s=80, c="red", label='Customer 1')
plt.scatter(X[y_kmeans == 1,0], X[y_kmeans  == 1,1], s=80, c="blue", label='Customer 2')
plt.scatter(X[y_kmeans == 2,0], X[y_kmeans  == 2,1], s=80, c="green", label='Customer 3')
plt.scatter(X[y_kmeans == 3,0], X[y_kmeans  == 3,1], s=80, c="yellow", label='Customer 4')
plt.scatter(X[y_kmeans == 4,0], X[y_kmeans  == 4,1], s=80, c="brown", label='Customer 5')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:, 1], s= 100, c='magenta', label= 'Centroids')
plt.title('Clusters of Customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
#1)Target group would be customer 2 with high spending score and high income
#2)60% of the customer 2 shoppers are women.we can do marketing campaign targeting popular items
#purchased by customers in this cluster
